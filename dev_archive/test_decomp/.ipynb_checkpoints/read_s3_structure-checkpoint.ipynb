# %%
# Retrieve the list of existing buckets
s3 = boto3.client('s3')
response = s3.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   mdp-spectralize-pal

# %%
import boto3

s3 = boto3.client('s3')

all_objects = s3.list_objects_v2(
Bucket='mdp-spectralize-pal',
Prefix='copied_audio/AC_DC',
MaxKeys=10)

# %%
import boto3
bucket = 'mdp-spectralize-pal'
#Make sure you provide / in the end
prefix = 'copied-audio/'  

client = boto3.client('s3')
result = client.list_objects(Bucket=bucket, Prefix=prefix, Delimiter='/')
for o in result.get('CommonPrefixes'):
    print ('sub folder : ', o.get('Prefix'))
# Out:
# sub folder :  copied-audio/634 Project and Toshiro Masuda/
# sub folder :  copied-audio/A Skylit Drive/
# sub folder :  copied-audio/AC_DC/
# sub folder :  copied-audio/Aaron Goldberg/
# sub folder :  copied-audio/Academy of St Martins in the Fields/
# sub folder :  copied-audio/Aceyalone and Rjd2/
# sub folder :  copied-audio/Aceyalone/
# sub folder :  copied-audio/Aisha Duo/
# sub folder :  copied-audio/Akeboshi/
# sub folder :  copied-audio/Alex Brandon/
# sub folder :  copied-audio/Alexander Brandon/
# sub folder :  copied-audio/Alkaline Trio/
# sub folder :  copied-audio/Allan Gray/
# sub folder :  copied-audio/An_Hero/
# sub folder :  copied-audio/Anarbor/
# sub folder :  copied-audio/Andrew Leman/
# sub folder :  copied-audio/Angels & Airwaves/
# sub folder :  copied-audio/Angels and Airwaves/
# sub folder :  copied-audio/Animal Collective/
# sub folder :  copied-audio/Animatic/
# sub folder :  copied-audio/Antaeus/
# sub folder :  copied-audio/Antonio Vivaldi/
# sub folder :  copied-audio/Aperture Science Psychoacoustics Laborat/
# sub folder :  copied-audio/Apocalyptica/
# sub folder :  copied-audio/Architects/
# sub folder :  copied-audio/Aretha Franklin/
# sub folder :  copied-audio/Arms For Legs/
# sub folder :  copied-audio/AspectOfTheStorm/
# sub folder :  copied-audio/At Vance/
# sub folder :  copied-audio/Audio Strobelight/
# sub folder :  copied-audio/Audiomachine/
# sub folder :  copied-audio/Aut0b0ts/
# sub folder :  copied-audio/Auto-Tune the News/
# sub folder :  copied-audio/B-52s/
# sub folder :  copied-audio/BBC Soundtracks/
# sub folder :  copied-audio/BT with Jan Johnston/
# sub folder :  copied-audio/BT/
# sub folder :  copied-audio/Bach (Slovak Chamber Orchestra)/
# sub folder :  copied-audio/Bachman-Turner Overdrive/
# sub folder :  copied-audio/Bad Boy, Good Man/
# sub folder :  copied-audio/Bad Religion/
# sub folder :  copied-audio/Bag Raiders/
# sub folder :  copied-audio/Baha Men/
# sub folder :  copied-audio/Bailongo/
# sub folder :  copied-audio/Bajofondo Tango Club/
# sub folder :  copied-audio/Bambee/
# sub folder :  copied-audio/Band of Horses/
# sub folder :  copied-audio/Bandits Of The Acoustic Revolution/
# sub folder :  copied-audio/Barenaked Ladies/
# sub folder :  copied-audio/Bastille/
# sub folder :  copied-audio/Bear McCreary/
# sub folder :  copied-audio/Beats Antique/
# sub folder :  copied-audio/Beck/
# sub folder :  copied-audio/Bee Gees/
# sub folder :  copied-audio/Beirut/
# sub folder :  copied-audio/Belle and Sebastian/
# sub folder :  copied-audio/Big D & The Kids Table/
# sub folder :  copied-audio/Big D and the Kids Table/
# sub folder :  copied-audio/Bill Engvall/
# sub folder :  copied-audio/Billie Holiday/
# sub folder :  copied-audio/Billy Munn/
# sub folder :  copied-audio/Bing Crosby/
# sub folder :  copied-audio/Bizet/
# sub folder :  copied-audio/Black Eyed Peas/
# sub folder :  copied-audio/Blackmill/
# sub folder :  copied-audio/Blackmoore's Night/
# sub folder :  copied-audio/Blink-182/
# sub folder :  copied-audio/Blue Collar Comedy Tour Rides Again/
# sub folder :  copied-audio/Blue Man Group/
# sub folder :  copied-audio/Blue Oyster Cult/
# sub folder :  copied-audio/Bob Crosby & the Bobcats/
# sub folder :  copied-audio/Bob Marley/
# sub folder :  copied-audio/Bobby Darin/
# sub folder :  copied-audio/Bon Jovi/
# sub folder :  copied-audio/Bond/
# sub folder :  copied-audio/Boston Legal/
# sub folder :  copied-audio/Boston Pops Orchestra/
# sub folder :  copied-audio/Bowling for Soup/
# sub folder :  copied-audio/Boys Like Girls/
# sub folder :  copied-audio/Brad Paisley/
# sub folder :  copied-audio/Break of Reality/
# sub folder :  copied-audio/Bright Eyes/
# sub folder :  copied-audio/Bright Eyes_Neva Dinova/
# sub folder :  copied-audio/Brokencyde/
# sub folder :  copied-audio/Brother Dege/
# sub folder :  copied-audio/Bruch/
# sub folder :  copied-audio/Bryan Ferry/
# sub folder :  copied-audio/C&C Music Factory/
# sub folder :  copied-audio/CBS - Survivor/
# sub folder :  copied-audio/CSI/
# sub folder :  copied-audio/Cab-Canavaralinfo/
# sub folder :  copied-audio/Cage the Elephant/
# sub folder :  copied-audio/Cake/
# sub folder :  copied-audio/Canteloube/
# sub folder :  copied-audio/Captured Music/
# sub folder :  copied-audio/Caravan Palace/
# sub folder :  copied-audio/Carl Orff/
# sub folder :  copied-audio/Carly Comando/
# sub folder :  copied-audio/Carter Burwell/
# sub folder :  copied-audio/Cascada/
# sub folder :  copied-audio/Cee Lo Green/
# sub folder :  copied-audio/Chad Van Dahm/
# sub folder :  copied-audio/Chameleon Circuit/
# sub folder :  copied-audio/Chamillionaire featuring Krayzie Bone/
# sub folder :  copied-audio/Chicago/
# sub folder :  copied-audio/Chiodos/
# sub folder :  copied-audio/Choir Of Former Altar Boys/
# sub folder :  copied-audio/Chris Landis/
# sub folder :  copied-audio/Christina Aguilera/
# sub folder :  copied-audio/City of Prague Philharmonic Orchestra/
# sub folder :  copied-audio/City of london Sinfonia/
# sub folder :  copied-audio/Claude Debussy/
# sub folder :  copied-audio/Clint Mansell/
# sub folder :  copied-audio/Cloud Atlas Original Soundtrack/
# sub folder :  copied-audio/Cloud Cult/
# sub folder :  copied-audio/Coheed & Cambria/
# sub folder :  copied-audio/Coheed And Cambria/
# sub folder :  copied-audio/Cohen/
# sub folder :  copied-audio/Coldplay/
# sub folder :  copied-audio/Cole Porter/
# sub folder :  copied-audio/Colin Hay/
# sub folder :  copied-audio/Compilations/
# sub folder :  copied-audio/Counting Crows/
# sub folder :  copied-audio/Creedence Clearwater Revival/
# sub folder :  copied-audio/Cursive/
# sub folder :  copied-audio/Cut Off Your Hands/
# sub folder :  copied-audio/DDR/
# sub folder :  copied-audio/DJ P0N-3/
# sub folder :  copied-audio/Daft Punk/
# sub folder :  copied-audio/Dagon Tabernacle Choir/
# sub folder :  copied-audio/Dane Cook/
# sub folder :  copied-audio/Daniel Powter/
# sub folder :  copied-audio/Daniel Tosh/
# sub folder :  copied-audio/Danny Kaye with The Andrews Sisters/
# sub folder :  copied-audio/Darren Hanlon/
# sub folder :  copied-audio/Darren Hayes/
# sub folder :  copied-audio/David Helfgott/
# sub folder :  copied-audio/David Lanz/
# sub folder :  copied-audio/David Newman/
# sub folder :  copied-audio/DeVotchKa/
# sub folder :  copied-audio/Dean Martin/
# sub folder :  copied-audio/Dear and the Headlights/
# sub folder :  copied-audio/Death Cab for Cutie/
# sub folder :  copied-audio/Deerhoof/
# sub folder :  copied-audio/Defcon/
# sub folder :  copied-audio/Demetri Martin/
# sub folder :  copied-audio/Derek Duke, Glenn Stafford & Russell Bro/
# sub folder :  copied-audio/Deus Ex/
# sub folder :  copied-audio/Dirty Heads/
# sub folder :  copied-audio/Disney/
# sub folder :  copied-audio/Dj Smallz and Cool & Dre/
# sub folder :  copied-audio/Don Davis/
# sub folder :  copied-audio/Dr Dissonance/
# sub folder :  copied-audio/Dr. Daniel Amen/
# sub folder :  copied-audio/Dr. Moira Gunn/
# sub folder :  copied-audio/Draft Week/
# sub folder :  copied-audio/DragonForce/
# sub folder :  copied-audio/Dschinghis Khan/
# sub folder :  copied-audio/Duke Ellington And His Orchestra/
# sub folder :  copied-audio/Dunwich Children's Chorale/
# sub folder :  copied-audio/E.S. Posthumus/
# sub folder :  copied-audio/Eddy Christiani & Frans Poptie/
# sub folder :  copied-audio/Edith Piaf/
# sub folder :  copied-audio/Edith Pilaf/
# sub folder :  copied-audio/Editors/
# sub folder :  copied-audio/Edward Shearmur/
# sub folder :  copied-audio/Eiffel 65/
# sub folder :  copied-audio/Eisley/
# sub folder :  copied-audio/Electrasy/
# sub folder :  copied-audio/Ella Fitzgerald with The Ink Spots/
# sub folder :  copied-audio/Elvis Presley/
# sub folder :  copied-audio/Emancipator/
# sub folder :  copied-audio/Eminem/
# sub folder :  copied-audio/Enrique Iglesias/
# sub folder :  copied-audio/Eric Johnson/
# sub folder :  copied-audio/Eric Serra/
# sub folder :  copied-audio/Escape the Fate/
# sub folder :  copied-audio/Eurobeat Brony/
# sub folder :  copied-audio/Everclear/
# sub folder :  copied-audio/Every Avenue/
# sub folder :  copied-audio/Everything/
# sub folder :  copied-audio/FAROFF/
# sub folder :  copied-audio/Fall Out Boy/
# sub folder :  copied-audio/Filmmusik/
# sub folder :  copied-audio/Firefly/
# sub folder :  copied-audio/Flashpoint/
# sub folder :  copied-audio/Fleur De Lavende/
# sub folder :  copied-audio/Flogging Molly/
# sub folder :  copied-audio/Florence and The Machine/
# sub folder :  copied-audio/Foo Fighters/
# sub folder :  copied-audio/Forty Winks/
# sub folder :  copied-audio/Fountains of Wayne/
# sub folder :  copied-audio/Frank Sinatra/
# sub folder :  copied-audio/Freelance Whales/
# sub folder :  copied-audio/Fun_/
# sub folder :  copied-audio/FurryFoxfire/
# sub folder :  copied-audio/Gabriel Iglesias/
# sub folder :  copied-audio/Gallows/
# sub folder :  copied-audio/Geinoh Yamashirogumi/
# sub folder :  copied-audio/Gene Wilder/
# sub folder :  copied-audio/Geoffrey Castle/
# sub folder :  copied-audio/George W. Bush/
# sub folder :  copied-audio/Gerhard Trede/
# sub folder :  copied-audio/Gladiator/
# sub folder :  copied-audio/God Is An Astronaut/
# sub folder :  copied-audio/Godsmack/
# sub folder :  copied-audio/Goldfinger/
# sub folder :  copied-audio/Goldfish/
# sub folder :  copied-audio/Goo Goo Dolls/
# sub folder :  copied-audio/Good Charlotte/
# sub folder :  copied-audio/Gorillaz/
# sub folder :  copied-audio/Gotye/
# sub folder :  copied-audio/Gramatik/
# sub folder :  copied-audio/Gravy Train/
# sub folder :  copied-audio/Great White/
# sub folder :  copied-audio/Green Day/
# sub folder :  copied-audio/Guillaume Bailey & Zak VanLier/
# sub folder :  copied-audio/Gunther/
# sub folder :  copied-audio/H. P. Lovecraft/
# sub folder :  copied-audio/Habib Koite & Bamada/
# sub folder :  copied-audio/Hank Snow/
# sub folder :  copied-audio/Hans Zimmer/
# sub folder :  copied-audio/Hans Zimmer_Lisa Gerrard/
# sub folder :  copied-audio/Hari Rao/
# sub folder :  copied-audio/Harry Christophers_The Sixteen/
# sub folder :  copied-audio/Hit The Lights/
# sub folder :  copied-audio/Hocus Pocus/
# sub folder :  copied-audio/Holly Long, Rebecca Marcotte And Tamara/
# sub folder :  copied-audio/Holst/
# sub folder :  copied-audio/Homestuck/
# sub folder :  copied-audio/Hoobastank/
# sub folder :  copied-audio/Hot Chelle Rae/
# sub folder :  copied-audio/Howard Shelley/
# sub folder :  copied-audio/Howard Shore/
# sub folder :  copied-audio/Hybrid/
# sub folder :  copied-audio/I Fight Dragons vs. Imogen Heap/
# sub folder :  copied-audio/I Fight Dragons/
# sub folder :  copied-audio/IN-GRID/
# sub folder :  copied-audio/Ian Van Dahl/
# sub folder :  copied-audio/Imagine Dragons/
# sub folder :  copied-audio/Immaculate Machine/
# sub folder :  copied-audio/In This Moment/
# sub folder :  copied-audio/Iron & Wine/
# sub folder :  copied-audio/Isaac Shepard/
# sub folder :  copied-audio/Israel Kamakawiwo'ole/
# sub folder :  copied-audio/J.D. Titan/
# sub folder :  copied-audio/Jack Shaindlin/
# sub folder :  copied-audio/Jackmove/
# sub folder :  copied-audio/Jake Waters/
# sub folder :  copied-audio/James Taylor/
# sub folder :  copied-audio/Jason Harwell/
# sub folder :  copied-audio/Jason Mraz/
# sub folder :  copied-audio/Jaymay/
# sub folder :  copied-audio/Jeff Danna & Mychael Danna/
# sub folder :  copied-audio/Jeff Foxworthy/
# sub folder :  copied-audio/Jennifer Thomas/
# sub folder :  copied-audio/Jeno Jando/
# sub folder :  copied-audio/Jeremy Soule & Julian Soule/
# sub folder :  copied-audio/Jerry Seinfeld/
# sub folder :  copied-audio/Jessie Primer III/
# sub folder :  copied-audio/Jim Gaffigan/
# sub folder :  copied-audio/Jimi Hendrix/
# sub folder :  copied-audio/Jimmy Buffett/
# sub folder :  copied-audio/Jimmy Eat World/
# sub folder :  copied-audio/Jimmy Sturr/
# sub folder :  copied-audio/Joan Jett and the Blackhearts/
# sub folder :  copied-audio/Joby Talbot/
# sub folder :  copied-audio/Joe Edmonds/
# sub folder :  copied-audio/Joe Hisaishi/
# sub folder :  copied-audio/Joe Stump/
# sub folder :  copied-audio/Johann Sebastian Bach/
# sub folder :  copied-audio/John Cougar Mellencamp/
# sub folder :  copied-audio/John Grout/
# sub folder :  copied-audio/John Mayer/
# sub folder :  copied-audio/John Stanford/
# sub folder :  copied-audio/John Williams/
# sub folder :  copied-audio/John Yelvington And The Scariachis/
# sub folder :  copied-audio/John Yelvington And The Shoggettes/
# sub folder :  copied-audio/Johnny Foreigner/
# sub folder :  copied-audio/Johnny Rivers/
# sub folder :  copied-audio/Jon Schmidt/
# sub folder :  copied-audio/Jonathan Coulton (Portal)/
# sub folder :  copied-audio/Joseph Svenson_RPO_Andre Previn/
# sub folder :  copied-audio/Josh Thoemke, Rebecca Marcotte And Matt/
# sub folder :  copied-audio/Journey/
# sub folder :  copied-audio/Juanes/
# sub folder :  copied-audio/Juno Reactor and Don Davis/
# sub folder :  copied-audio/Karsh Kale/
# sub folder :  copied-audio/Katy Perry/
# sub folder :  copied-audio/Ki_Theory/
# sub folder :  copied-audio/Klaus Badelt/
# sub folder :  copied-audio/Klaxons/
# sub folder :  copied-audio/Kow Otani/
# sub folder :  copied-audio/Kraddy/
# sub folder :  copied-audio/Krewella/
# sub folder :  copied-audio/Kriesler/
# sub folder :  copied-audio/Lance J. Holt/
# sub folder :  copied-audio/Led Zeppelin/
# sub folder :  copied-audio/Left Alone/
# sub folder :  copied-audio/Less Than Jake/
# sub folder :  copied-audio/Level 70 Elite Tauren Chieftain/
# sub folder :  copied-audio/Liam Murphy/
# sub folder :  copied-audio/Lifescapes Anniversary/
# sub folder :  copied-audio/Lily Allen/
# sub folder :  copied-audio/Lindsey Stirling/
# sub folder :  copied-audio/Linkin Park/
# sub folder :  copied-audio/Living In Pretend/
# sub folder :  copied-audio/Living Tombstone/
# sub folder :  copied-audio/Loggins and Messina/
# sub folder :  copied-audio/London Symphony Orchestra/
# sub folder :  copied-audio/Louis Armstrong/
# sub folder :  copied-audio/Lovehatehero/
# sub folder :  copied-audio/Lucas Arts/
# sub folder :  copied-audio/Luciana Souza/
# sub folder :  copied-audio/Ludovico Einaudi/
# sub folder :  copied-audio/Luigi Boccherini/
# sub folder :  copied-audio/Lyre Le Temps/
# sub folder :  copied-audio/M.C. Hammer/
# sub folder :  copied-audio/MGMT/
# sub folder :  copied-audio/MOVITS/
# sub folder :  copied-audio/Madina Lake/
# sub folder :  copied-audio/Mae/
# sub folder :  copied-audio/Mandy Moore/
# sub folder :  copied-audio/Marius de Vries_Michelle De Vries_Stuart/
# sub folder :  copied-audio/Maroon 5/
# sub folder :  copied-audio/Martin O'Donnell & Michael Salvatori/
# sub folder :  copied-audio/Martin O'Donnell_Michael Salvatori/
# sub folder :  copied-audio/Massive Attack/
# sub folder :  copied-audio/Matchbox 20/
# sub folder :  copied-audio/Matt & Kim/
# sub folder :  copied-audio/Matt Fahey, Jennifer Taub And Josh Thoem/
# sub folder :  copied-audio/Matt Fahey/
# sub folder :  copied-audio/Matt and Kim/
# sub folder :  copied-audio/Maxwell Davies/
# sub folder :  copied-audio/Men Without Hats/
# sub folder :  copied-audio/Metric/
# sub folder :  copied-audio/Michael Andrews/
# sub folder :  copied-audio/Mike Morasky/
# sub folder :  copied-audio/Miracles of Modern Science/
# sub folder :  copied-audio/Moby & Oscar The Punk/
# sub folder :  copied-audio/Moby/
# sub folder :  copied-audio/Modest Mouse/
# sub folder :  copied-audio/Modest Mouse_Ratatat/
# sub folder :  copied-audio/Mogwai/
# sub folder :  copied-audio/Molly Jenson/
# sub folder :  copied-audio/Mono & World's End Girlfriend/
# sub folder :  copied-audio/Mop Mop/
# sub folder :  copied-audio/Motion City Soundtrack/
# sub folder :  copied-audio/Mozart/
# sub folder :  copied-audio/Mumford and Sons/
# sub folder :  copied-audio/Muse/
# sub folder :  copied-audio/My Brightest Diamond/
# sub folder :  copied-audio/My Chemical Romance/
# sub folder :  copied-audio/NOFX/
# sub folder :  copied-audio/NPR/
# sub folder :  copied-audio/Naive Thieves/
# sub folder :  copied-audio/Naruto/
# sub folder :  copied-audio/Nash Ensemble_Libor Pesek/
# sub folder :  copied-audio/Nasty Facts/
# sub folder :  copied-audio/Neon Trees/
# sub folder :  copied-audio/Neutral Milk Hotel/
# sub folder :  copied-audio/New Stories/
# sub folder :  copied-audio/Newton/
# sub folder :  copied-audio/Nick Cave & Warren Ellis/
# sub folder :  copied-audio/Nick Cave , Warren Ellis/
# sub folder :  copied-audio/Nickelback/
# sub folder :  copied-audio/Nintendo Games/
# sub folder :  copied-audio/Nirvana/
# sub folder :  copied-audio/No artist info/
# sub folder :  copied-audio/Nobuo Uematsu/
# sub folder :  copied-audio/Novak/
# sub folder :  copied-audio/Nox Arcana/
# sub folder :  copied-audio/O'Reilly Media Where 2.0 Conference/
# sub folder :  copied-audio/O-Zone/
# sub folder :  copied-audio/OCRemix/
# sub folder :  copied-audio/OSCON Europe 2005/
# sub folder :  copied-audio/Ocean Is Theory/
# sub folder :  copied-audio/Of Monsters and Men/
# sub folder :  copied-audio/Of Montreal/
# sub folder :  copied-audio/Offenbach/
# sub folder :  copied-audio/Ohio Valley Spirits/
# sub folder :  copied-audio/Ok Go/
# sub folder :  copied-audio/Olafur Arnalds/
# sub folder :  copied-audio/OneRepublic_Beyonce_Liam Murphy/
# sub folder :  copied-audio/Original Soundtrack/
# sub folder :  copied-audio/Original Soundtracks/
# sub folder :  copied-audio/Outkast/
# sub folder :  copied-audio/Pachelbel/
# sub folder :  copied-audio/Packy Lundholm/
# sub folder :  copied-audio/Papa Roach/
# sub folder :  copied-audio/Paramore/
# sub folder :  copied-audio/Parov Stelar feat. Anduze/
# sub folder :  copied-audio/Parov Stelar feat. Cleo Panther/
# sub folder :  copied-audio/Parov Stelar feat. Jerry Di Monza/
# sub folder :  copied-audio/Parov Stelar feat. Lilja Bloom/
# sub folder :  copied-audio/Parov Stelar feat. Max The Sax/
# sub folder :  copied-audio/Parov Stelar/
# sub folder :  copied-audio/Pascal Marcotte And The Randolph Carters/
# sub folder :  copied-audio/Paul Cardall/
# sub folder :  copied-audio/Paul Oakenfold/
# sub folder :  copied-audio/Peter Jennison/
# sub folder :  copied-audio/Peter Schilling/
# sub folder :  copied-audio/Philadelphia Orchestra, Riccardo Muti &/
# sub folder :  copied-audio/Philharmonia Moscow/
# sub folder :  copied-audio/Philharmonia Orchestra/
# sub folder :  copied-audio/Philip Glass/
# sub folder :  copied-audio/PiercingSight (composed by)/
# sub folder :  copied-audio/PiercingSight/
# sub folder :  copied-audio/Pinback/
# sub folder :  copied-audio/Pinchas Zukerman _ Mark Neikrug/
# sub folder :  copied-audio/Pink Floyd/
# sub folder :  copied-audio/Pink/
# sub folder :  copied-audio/PinkiePieSwear/
# sub folder :  copied-audio/Plumb/
# sub folder :  copied-audio/Podcasts/
# sub folder :  copied-audio/Ponyo/
# sub folder :  copied-audio/Portal/
# sub folder :  copied-audio/Pull Tiger Tail/
# sub folder :  copied-audio/Quadro Nuevo/
# sub folder :  copied-audio/Quantic Soul Orchestra/
# sub folder :  copied-audio/Quantic/
# sub folder :  copied-audio/Queen/
# sub folder :  copied-audio/R.E.M_/
# sub folder :  copied-audio/R.X.R.A/
# sub folder :  copied-audio/RJD2/
# sub folder :  copied-audio/Rachmaninov/
# sub folder :  copied-audio/Ramin Djawadi/
# sub folder :  copied-audio/Ramona Falls/
# sub folder :  copied-audio/Randy Edelman/
# sub folder :  copied-audio/Ratatat/
# sub folder :  copied-audio/Rebecca Marcotte And Josh Thoemke/
# sub folder :  copied-audio/Red Hot Chilli Peppers/
# sub folder :  copied-audio/Reel Big Fish/
# sub folder :  copied-audio/Reeves Gabrels/
# sub folder :  copied-audio/Requiem For A Dream/
# sub folder :  copied-audio/Reservoir Ticklers/
# sub folder :  copied-audio/Richard Searles/
# sub folder :  copied-audio/Ricky Martin/
# sub folder :  copied-audio/Riot Games/
# sub folder :  copied-audio/Riyu Kosaka/
# sub folder :  copied-audio/Rob Dougan/
# sub folder :  copied-audio/Rob Thomas/
# sub folder :  copied-audio/Robin Williams/
# sub folder :  copied-audio/Rodrigo y Gabriela/
# sub folder :  copied-audio/Roger Waters/
# sub folder :  copied-audio/Rostropovich/
# sub folder :  copied-audio/Roy Brown/
# sub folder :  copied-audio/Royal Liverpool Philharmonic orchestra/
# sub folder :  copied-audio/Royal Philharmonic Orchestra/
# sub folder :  copied-audio/Royksopp/
# sub folder :  copied-audio/Rupert Holmes/
# sub folder :  copied-audio/Russell Brower & The Eminence Symphony O/
# sub folder :  copied-audio/Rusted Root/
# sub folder :  copied-audio/Saliva/
# sub folder :  copied-audio/Saltillo/
# sub folder :  copied-audio/Santana/
# sub folder :  copied-audio/Saxon Shore/
# sub folder :  copied-audio/Schubert/
# sub folder :  copied-audio/Scissor Sisters/
# sub folder :  copied-audio/Scryden Broken Wings/
# sub folder :  copied-audio/Sean Paul/
# sub folder :  copied-audio/Shad/
# sub folder :  copied-audio/Shiny Toy Guns/
# sub folder :  copied-audio/Shostakovich/
# sub folder :  copied-audio/Sid Phillips/
# sub folder :  copied-audio/Sifl & Olly/
# sub folder :  copied-audio/Sigur Rós/
# sub folder :  copied-audio/Simple Plan/
# sub folder :  copied-audio/Sing It Loud/
# sub folder :  copied-audio/Sir Georg Solti & Wiener Philharmoniker/
# sub folder :  copied-audio/Sir Mix-A-Lot/
# sub folder :  copied-audio/Skream & Example/
# sub folder :  copied-audio/Skrillex/
# sub folder :  copied-audio/Slapbak/
# sub folder :  copied-audio/Slovak Philharmonic Orchestra/
# sub folder :  copied-audio/Smash Mouth/
# sub folder :  copied-audio/SmashMouth/
# sub folder :  copied-audio/Smile Empty Soul/
# sub folder :  copied-audio/Someone Still Loves You Boris Yeltsin/
# sub folder :  copied-audio/Someone Still Loves You, Boris Yeltsin/
# sub folder :  copied-audio/Sonny Rollins With the Modern Jazz Quart/
# sub folder :  copied-audio/Soul Position/
# sub folder :  copied-audio/Soundtrack/
# sub folder :  copied-audio/South Park/
# sub folder :  copied-audio/Spanish National orchestra/
# sub folder :  copied-audio/Spoon/
# sub folder :  copied-audio/Starting Line/
# sub folder :  copied-audio/Stevie Wonder/
# sub folder :  copied-audio/Sting & The Police/
# sub folder :  copied-audio/Street Fighter 4/
# sub folder :  copied-audio/Streetlight Manifesto/
# sub folder :  copied-audio/String Quartet Tribute/
# sub folder :  copied-audio/Stromae/
# sub folder :  copied-audio/Sublime/
# sub folder :  copied-audio/Super Furry Animals/
# sub folder :  copied-audio/Survivor/
# sub folder :  copied-audio/Swarms/
# sub folder :  copied-audio/System Of A Down/
# sub folder :  copied-audio/T. Colin Campbell/
# sub folder :  copied-audio/TAT/
# sub folder :  copied-audio/TJ & The Revo/
# sub folder :  copied-audio/TV on the Radio/
# sub folder :  copied-audio/TV_TV/
# sub folder :  copied-audio/Tamara McDonough/
# sub folder :  copied-audio/Tamara/
# sub folder :  copied-audio/Tangerine Dream/
# sub folder :  copied-audio/Tavener/
# sub folder :  copied-audio/Tchaikovsky/
# sub folder :  copied-audio/Tears for Fears/
# sub folder :  copied-audio/Ted Leo & the Pharmacists/
# sub folder :  copied-audio/Tegan & Sara/
# sub folder :  copied-audio/Tex Beneke/
# sub folder :  copied-audio/The 5, 6, 7, 8's/
# sub folder :  copied-audio/The Adicts/
# sub folder :  copied-audio/The All-American Rejects/
# sub folder :  copied-audio/The American Dollar/
# sub folder :  copied-audio/The Aquabats/
# sub folder :  copied-audio/The Arkham Carolers/
# sub folder :  copied-audio/The Ataris/
# sub folder :  copied-audio/The Avalanches/
# sub folder :  copied-audio/The Beatles/
# sub folder :  copied-audio/The Blow/
# sub folder :  copied-audio/The Bouncing Souls/
# sub folder :  copied-audio/The Brand New Heavies/
# sub folder :  copied-audio/The Clash/
# sub folder :  copied-audio/The Clockwork Quartet/
# sub folder :  copied-audio/The Darkness/
# sub folder :  copied-audio/The Decemberists/
# sub folder :  copied-audio/The Fray/
# sub folder :  copied-audio/The Friendly Indians/
# sub folder :  copied-audio/The Go! Train/
# sub folder :  copied-audio/The Gories/
# sub folder :  copied-audio/The H.P. Lovecraft Historical Society/
# sub folder :  copied-audio/The Homestuck Fan Musicians/
# sub folder :  copied-audio/The Hush Sound/
# sub folder :  copied-audio/The Ink Spots/
# sub folder :  copied-audio/The Intelligence/
# sub folder :  copied-audio/The Killers/
# sub folder :  copied-audio/The Kinks/
# sub folder :  copied-audio/The Limp Twins/
# sub folder :  copied-audio/The London Symphony Orchestra/
# sub folder :  copied-audio/The Magnetic Fields/
# sub folder :  copied-audio/The Maine/
# sub folder :  copied-audio/The Meatmean/
# sub folder :  copied-audio/The Mountain Goats/
# sub folder :  copied-audio/The New Pornographers/
# sub folder :  copied-audio/The Number Twelve Looks Like You/
# sub folder :  copied-audio/The Offspring/
# sub folder :  copied-audio/The Piano Guys/
# sub folder :  copied-audio/The Pixies/
# sub folder :  copied-audio/The Police/
# sub folder :  copied-audio/The Posies/
# sub folder :  copied-audio/The Proclaimers/
# sub folder :  copied-audio/The Ramones/
# sub folder :  copied-audio/The Rolling Stones/
# sub folder :  copied-audio/The Section Quartet/
# sub folder :  copied-audio/The Shins/
# sub folder :  copied-audio/The Strokes/
# sub folder :  copied-audio/The Sugarhill Gang/
# sub folder :  copied-audio/The Vandals/
# sub folder :  copied-audio/The Vapors/
# sub folder :  copied-audio/The Venetia Fair/
# sub folder :  copied-audio/The Verve/
# sub folder :  copied-audio/The White Tie Affair/
# sub folder :  copied-audio/The Who/
# sub folder :  copied-audio/The Winterpills/
# sub folder :  copied-audio/The _Once_ Soundtrack/
# sub folder :  copied-audio/Theophany/
# sub folder :  copied-audio/There for Tomorrow/
# sub folder :  copied-audio/These Green Eyes/
# sub folder :  copied-audio/Thin Lizzy/
# sub folder :  copied-audio/Third Eye Blind/
# sub folder :  copied-audio/Thomas Newman/
# sub folder :  copied-audio/Tilly and the Wall/
# sub folder :  copied-audio/Tim Janis/
# sub folder :  copied-audio/Timothy Vajda/
# sub folder :  copied-audio/Tiny Tim/
# sub folder :  copied-audio/Tomoyasu Hotei/
# sub folder :  copied-audio/Toshiro Masuda/
# sub folder :  copied-audio/Train/
# sub folder :  copied-audio/Trans-Siberian Orchestra/
# sub folder :  copied-audio/Transformers/
# sub folder :  copied-audio/Travis Lien/
# sub folder :  copied-audio/Trevor Morris/
# sub folder :  copied-audio/Trevor Rabin/
# sub folder :  copied-audio/Two Steps From Hell/
# sub folder :  copied-audio/Tycho/
# sub folder :  copied-audio/Tyler Bates/
# sub folder :  copied-audio/U2/
# sub folder :  copied-audio/Ulster Orchestra/
# sub folder :  copied-audio/Uncle Brian/
# sub folder :  copied-audio/Valencia/
# sub folder :  copied-audio/Vampire Weekend/
# sub folder :  copied-audio/Vanessa-Mae/
# sub folder :  copied-audio/Vangelis/
# sub folder :  copied-audio/Vanilla Ice/
# sub folder :  copied-audio/Varios interpretes/
# sub folder :  copied-audio/Various Artists/
# sub folder :  copied-audio/Various/
# sub folder :  copied-audio/Vertical Horizon/
# sub folder :  copied-audio/Viva Voce/
# sub folder :  copied-audio/WGBH Science Unit/
# sub folder :  copied-audio/Walk The Moon/
# sub folder :  copied-audio/Wang Lee Hom/
# sub folder :  copied-audio/Wayne Jones/
# sub folder :  copied-audio/Weezer/
# sub folder :  copied-audio/Weird Al Yankovic/
# sub folder :  copied-audio/WhiteNoise Lab/
# sub folder :  copied-audio/Will Post/
# sub folder :  copied-audio/Witches/
# sub folder :  copied-audio/Xihilisk/
# sub folder :  copied-audio/Yeah Yeah Yeahs/
# sub folder :  copied-audio/Yes/
# sub folder :  copied-audio/Yiruma/
# sub folder :  copied-audio/Yo La Tengo/
# sub folder :  copied-audio/Yo-Yo Ma/
# sub folder :  copied-audio/Youth Group/
# sub folder :  copied-audio/Zoe Keating/
# sub folder :  copied-audio/_Weird Al_ Yankovic/
# sub folder :  copied-audio/_unsorted/

# %%
# Out:
# sub folder :  copied-audio/634 Project and Toshiro Masuda/
# sub folder :  copied-audio/A Skylit Drive/
# sub folder :  copied-audio/AC_DC/
# sub folder :  copied-audio/Aaron Goldberg/
# sub folder :  copied-audio/Academy of St Martins in the Fields/
# sub folder :  copied-audio/Aceyalone and Rjd2/
# sub folder :  copied-audio/Aceyalone/
# sub folder :  copied-audio/Aisha Duo/
# sub folder :  copied-audio/Akeboshi/
# sub folder :  copied-audio/Alex Brandon/
# sub folder :  copied-audio/Alexander Brandon/
# sub folder :  copied-audio/Alkaline Trio/
# sub folder :  copied-audio/Allan Gray/
# sub folder :  copied-audio/An_Hero/
# sub folder :  copied-audio/Anarbor/
# sub folder :  copied-audio/Andrew Leman/
# sub folder :  copied-audio/Angels & Airwaves/
# sub folder :  copied-audio/Angels and Airwaves/
# sub folder :  copied-audio/Animal Collective/
# sub folder :  copied-audio/Animatic/
# sub folder :  copied-audio/Antaeus/
# sub folder :  copied-audio/Antonio Vivaldi/
# sub folder :  copied-audio/Aperture Science Psychoacoustics Laborat/
# sub folder :  copied-audio/Apocalyptica/
# sub folder :  copied-audio/Architects/
# sub folder :  copied-audio/Aretha Franklin/
# sub folder :  copied-audio/Arms For Legs/
# sub folder :  copied-audio/AspectOfTheStorm/
# sub folder :  copied-audio/At Vance/
# sub folder :  copied-audio/Audio Strobelight/
# sub folder :  copied-audio/Audiomachine/
# sub folder :  copied-audio/Aut0b0ts/
# sub folder :  copied-audio/Auto-Tune the News/
# sub folder :  copied-audio/B-52s/
# sub folder :  copied-audio/BBC Soundtracks/
# sub folder :  copied-audio/BT with Jan Johnston/
# sub folder :  copied-audio/BT/
# sub folder :  copied-audio/Bach (Slovak Chamber Orchestra)/
# sub folder :  copied-audio/Bachman-Turner Overdrive/
# sub folder :  copied-audio/Bad Boy, Good Man/
# sub folder :  copied-audio/Bad Religion/
# sub folder :  copied-audio/Bag Raiders/
# sub folder :  copied-audio/Baha Men/
# sub folder :  copied-audio/Bailongo/
# sub folder :  copied-audio/Bajofondo Tango Club/
# sub folder :  copied-audio/Bambee/
# sub folder :  copied-audio/Band of Horses/
# sub folder :  copied-audio/Bandits Of The Acoustic Revolution/
# sub folder :  copied-audio/Barenaked Ladies/
# sub folder :  copied-audio/Bastille/
# sub folder :  copied-audio/Bear McCreary/
# sub folder :  copied-audio/Beats Antique/
# sub folder :  copied-audio/Beck/
# sub folder :  copied-audio/Bee Gees/
# sub folder :  copied-audio/Beirut/
# sub folder :  copied-audio/Belle and Sebastian/
# sub folder :  copied-audio/Big D & The Kids Table/
# sub folder :  copied-audio/Big D and the Kids Table/
# sub folder :  copied-audio/Bill Engvall/
# sub folder :  copied-audio/Billie Holiday/
# sub folder :  copied-audio/Billy Munn/
# sub folder :  copied-audio/Bing Crosby/
# sub folder :  copied-audio/Bizet/
# sub folder :  copied-audio/Black Eyed Peas/
# sub folder :  copied-audio/Blackmill/
# sub folder :  copied-audio/Blackmoore's Night/
# sub folder :  copied-audio/Blink-182/
# sub folder :  copied-audio/Blue Collar Comedy Tour Rides Again/
# sub folder :  copied-audio/Blue Man Group/
# sub folder :  copied-audio/Blue Oyster Cult/
# sub folder :  copied-audio/Bob Crosby & the Bobcats/
# sub folder :  copied-audio/Bob Marley/
# sub folder :  copied-audio/Bobby Darin/
# sub folder :  copied-audio/Bon Jovi/
# sub folder :  copied-audio/Bond/
# sub folder :  copied-audio/Boston Legal/
# sub folder :  copied-audio/Boston Pops Orchestra/
# sub folder :  copied-audio/Bowling for Soup/
# sub folder :  copied-audio/Boys Like Girls/
# sub folder :  copied-audio/Brad Paisley/
# sub folder :  copied-audio/Break of Reality/
# sub folder :  copied-audio/Bright Eyes/
# sub folder :  copied-audio/Bright Eyes_Neva Dinova/
# sub folder :  copied-audio/Brokencyde/
# sub folder :  copied-audio/Brother Dege/
# sub folder :  copied-audio/Bruch/
# sub folder :  copied-audio/Bryan Ferry/
# sub folder :  copied-audio/C&C Music Factory/
# sub folder :  copied-audio/CBS - Survivor/
# sub folder :  copied-audio/CSI/
# sub folder :  copied-audio/Cab-Canavaralinfo/
# sub folder :  copied-audio/Cage the Elephant/
# sub folder :  copied-audio/Cake/
# sub folder :  copied-audio/Canteloube/
# sub folder :  copied-audio/Captured Music/
# sub folder :  copied-audio/Caravan Palace/
# sub folder :  copied-audio/Carl Orff/
# sub folder :  copied-audio/Carly Comando/
# sub folder :  copied-audio/Carter Burwell/
# sub folder :  copied-audio/Cascada/
# sub folder :  copied-audio/Cee Lo Green/
# sub folder :  copied-audio/Chad Van Dahm/
# sub folder :  copied-audio/Chameleon Circuit/
# sub folder :  copied-audio/Chamillionaire featuring Krayzie Bone/
# sub folder :  copied-audio/Chicago/
# sub folder :  copied-audio/Chiodos/
# sub folder :  copied-audio/Choir Of Former Altar Boys/
# sub folder :  copied-audio/Chris Landis/
# sub folder :  copied-audio/Christina Aguilera/
# sub folder :  copied-audio/City of Prague Philharmonic Orchestra/
# sub folder :  copied-audio/City of london Sinfonia/
# sub folder :  copied-audio/Claude Debussy/
# sub folder :  copied-audio/Clint Mansell/
# sub folder :  copied-audio/Cloud Atlas Original Soundtrack/
# sub folder :  copied-audio/Cloud Cult/
# sub folder :  copied-audio/Coheed & Cambria/
# sub folder :  copied-audio/Coheed And Cambria/
# sub folder :  copied-audio/Cohen/
# sub folder :  copied-audio/Coldplay/
# sub folder :  copied-audio/Cole Porter/
# sub folder :  copied-audio/Colin Hay/
# sub folder :  copied-audio/Compilations/
# sub folder :  copied-audio/Counting Crows/
# sub folder :  copied-audio/Creedence Clearwater Revival/
# sub folder :  copied-audio/Cursive/
# sub folder :  copied-audio/Cut Off Your Hands/
# sub folder :  copied-audio/DDR/
# sub folder :  copied-audio/DJ P0N-3/
# sub folder :  copied-audio/Daft Punk/
# sub folder :  copied-audio/Dagon Tabernacle Choir/
# sub folder :  copied-audio/Dane Cook/
# sub folder :  copied-audio/Daniel Powter/
# sub folder :  copied-audio/Daniel Tosh/
# sub folder :  copied-audio/Danny Kaye with The Andrews Sisters/
# sub folder :  copied-audio/Darren Hanlon/
# sub folder :  copied-audio/Darren Hayes/
# sub folder :  copied-audio/David Helfgott/
# sub folder :  copied-audio/David Lanz/
# sub folder :  copied-audio/David Newman/
# sub folder :  copied-audio/DeVotchKa/
# sub folder :  copied-audio/Dean Martin/
# sub folder :  copied-audio/Dear and the Headlights/
# sub folder :  copied-audio/Death Cab for Cutie/
# sub folder :  copied-audio/Deerhoof/
# sub folder :  copied-audio/Defcon/
# sub folder :  copied-audio/Demetri Martin/
# sub folder :  copied-audio/Derek Duke, Glenn Stafford & Russell Bro/
# sub folder :  copied-audio/Deus Ex/
# sub folder :  copied-audio/Dirty Heads/
# sub folder :  copied-audio/Disney/
# sub folder :  copied-audio/Dj Smallz and Cool & Dre/
# sub folder :  copied-audio/Don Davis/
# sub folder :  copied-audio/Dr Dissonance/
# sub folder :  copied-audio/Dr. Daniel Amen/
# sub folder :  copied-audio/Dr. Moira Gunn/
# sub folder :  copied-audio/Draft Week/
# sub folder :  copied-audio/DragonForce/
# sub folder :  copied-audio/Dschinghis Khan/
# sub folder :  copied-audio/Duke Ellington And His Orchestra/
# sub folder :  copied-audio/Dunwich Children's Chorale/
# sub folder :  copied-audio/E.S. Posthumus/
# sub folder :  copied-audio/Eddy Christiani & Frans Poptie/
# sub folder :  copied-audio/Edith Piaf/
# sub folder :  copied-audio/Edith Pilaf/
# sub folder :  copied-audio/Editors/
# sub folder :  copied-audio/Edward Shearmur/
# sub folder :  copied-audio/Eiffel 65/
# sub folder :  copied-audio/Eisley/
# sub folder :  copied-audio/Electrasy/
# sub folder :  copied-audio/Ella Fitzgerald with The Ink Spots/
# sub folder :  copied-audio/Elvis Presley/
# sub folder :  copied-audio/Emancipator/
# sub folder :  copied-audio/Eminem/
# sub folder :  copied-audio/Enrique Iglesias/
# sub folder :  copied-audio/Eric Johnson/
# sub folder :  copied-audio/Eric Serra/
# sub folder :  copied-audio/Escape the Fate/
# sub folder :  copied-audio/Eurobeat Brony/
# sub folder :  copied-audio/Everclear/
# sub folder :  copied-audio/Every Avenue/
# sub folder :  copied-audio/Everything/
# sub folder :  copied-audio/FAROFF/
# sub folder :  copied-audio/Fall Out Boy/
# sub folder :  copied-audio/Filmmusik/
# sub folder :  copied-audio/Firefly/
# sub folder :  copied-audio/Flashpoint/
# sub folder :  copied-audio/Fleur De Lavende/
# sub folder :  copied-audio/Flogging Molly/
# sub folder :  copied-audio/Florence and The Machine/
# sub folder :  copied-audio/Foo Fighters/
# sub folder :  copied-audio/Forty Winks/
# sub folder :  copied-audio/Fountains of Wayne/
# sub folder :  copied-audio/Frank Sinatra/
# sub folder :  copied-audio/Freelance Whales/
# sub folder :  copied-audio/Fun_/
# sub folder :  copied-audio/FurryFoxfire/
# sub folder :  copied-audio/Gabriel Iglesias/
# sub folder :  copied-audio/Gallows/
# sub folder :  copied-audio/Geinoh Yamashirogumi/
# sub folder :  copied-audio/Gene Wilder/
# sub folder :  copied-audio/Geoffrey Castle/
# sub folder :  copied-audio/George W. Bush/
# sub folder :  copied-audio/Gerhard Trede/
# sub folder :  copied-audio/Gladiator/
# sub folder :  copied-audio/God Is An Astronaut/
# sub folder :  copied-audio/Godsmack/
# sub folder :  copied-audio/Goldfinger/
# sub folder :  copied-audio/Goldfish/
# sub folder :  copied-audio/Goo Goo Dolls/
# sub folder :  copied-audio/Good Charlotte/
# sub folder :  copied-audio/Gorillaz/
# sub folder :  copied-audio/Gotye/
# sub folder :  copied-audio/Gramatik/
# sub folder :  copied-audio/Gravy Train/
# sub folder :  copied-audio/Great White/
# sub folder :  copied-audio/Green Day/
# sub folder :  copied-audio/Guillaume Bailey & Zak VanLier/
# sub folder :  copied-audio/Gunther/
# sub folder :  copied-audio/H. P. Lovecraft/
# sub folder :  copied-audio/Habib Koite & Bamada/
# sub folder :  copied-audio/Hank Snow/
# sub folder :  copied-audio/Hans Zimmer/
# sub folder :  copied-audio/Hans Zimmer_Lisa Gerrard/
# sub folder :  copied-audio/Hari Rao/
# sub folder :  copied-audio/Harry Christophers_The Sixteen/
# sub folder :  copied-audio/Hit The Lights/
# sub folder :  copied-audio/Hocus Pocus/
# sub folder :  copied-audio/Holly Long, Rebecca Marcotte And Tamara/
# sub folder :  copied-audio/Holst/
# sub folder :  copied-audio/Homestuck/
# sub folder :  copied-audio/Hoobastank/
# sub folder :  copied-audio/Hot Chelle Rae/
# sub folder :  copied-audio/Howard Shelley/
# sub folder :  copied-audio/Howard Shore/
# sub folder :  copied-audio/Hybrid/
# sub folder :  copied-audio/I Fight Dragons vs. Imogen Heap/
# sub folder :  copied-audio/I Fight Dragons/
# sub folder :  copied-audio/IN-GRID/
# sub folder :  copied-audio/Ian Van Dahl/
# sub folder :  copied-audio/Imagine Dragons/
# sub folder :  copied-audio/Immaculate Machine/
# sub folder :  copied-audio/In This Moment/
# sub folder :  copied-audio/Iron & Wine/
# sub folder :  copied-audio/Isaac Shepard/
# sub folder :  copied-audio/Israel Kamakawiwo'ole/
# sub folder :  copied-audio/J.D. Titan/
# sub folder :  copied-audio/Jack Shaindlin/
# sub folder :  copied-audio/Jackmove/
# sub folder :  copied-audio/Jake Waters/
# sub folder :  copied-audio/James Taylor/
# sub folder :  copied-audio/Jason Harwell/
# sub folder :  copied-audio/Jason Mraz/
# sub folder :  copied-audio/Jaymay/
# sub folder :  copied-audio/Jeff Danna & Mychael Danna/
# sub folder :  copied-audio/Jeff Foxworthy/
# sub folder :  copied-audio/Jennifer Thomas/
# sub folder :  copied-audio/Jeno Jando/
# sub folder :  copied-audio/Jeremy Soule & Julian Soule/
# sub folder :  copied-audio/Jerry Seinfeld/
# sub folder :  copied-audio/Jessie Primer III/
# sub folder :  copied-audio/Jim Gaffigan/
# sub folder :  copied-audio/Jimi Hendrix/
# sub folder :  copied-audio/Jimmy Buffett/
# sub folder :  copied-audio/Jimmy Eat World/
# sub folder :  copied-audio/Jimmy Sturr/
# sub folder :  copied-audio/Joan Jett and the Blackhearts/
# sub folder :  copied-audio/Joby Talbot/
# sub folder :  copied-audio/Joe Edmonds/
# sub folder :  copied-audio/Joe Hisaishi/
# sub folder :  copied-audio/Joe Stump/
# sub folder :  copied-audio/Johann Sebastian Bach/
# sub folder :  copied-audio/John Cougar Mellencamp/
# sub folder :  copied-audio/John Grout/
# sub folder :  copied-audio/John Mayer/
# sub folder :  copied-audio/John Stanford/
# sub folder :  copied-audio/John Williams/
# sub folder :  copied-audio/John Yelvington And The Scariachis/
# sub folder :  copied-audio/John Yelvington And The Shoggettes/
# sub folder :  copied-audio/Johnny Foreigner/
# sub folder :  copied-audio/Johnny Rivers/
# sub folder :  copied-audio/Jon Schmidt/
# sub folder :  copied-audio/Jonathan Coulton (Portal)/
# sub folder :  copied-audio/Joseph Svenson_RPO_Andre Previn/
# sub folder :  copied-audio/Josh Thoemke, Rebecca Marcotte And Matt/
# sub folder :  copied-audio/Journey/
# sub folder :  copied-audio/Juanes/
# sub folder :  copied-audio/Juno Reactor and Don Davis/
# sub folder :  copied-audio/Karsh Kale/
# sub folder :  copied-audio/Katy Perry/
# sub folder :  copied-audio/Ki_Theory/
# sub folder :  copied-audio/Klaus Badelt/
# sub folder :  copied-audio/Klaxons/
# sub folder :  copied-audio/Kow Otani/
# sub folder :  copied-audio/Kraddy/
# sub folder :  copied-audio/Krewella/
# sub folder :  copied-audio/Kriesler/
# sub folder :  copied-audio/Lance J. Holt/
# sub folder :  copied-audio/Led Zeppelin/
# sub folder :  copied-audio/Left Alone/
# sub folder :  copied-audio/Less Than Jake/
# sub folder :  copied-audio/Level 70 Elite Tauren Chieftain/
# sub folder :  copied-audio/Liam Murphy/
# sub folder :  copied-audio/Lifescapes Anniversary/
# sub folder :  copied-audio/Lily Allen/
# sub folder :  copied-audio/Lindsey Stirling/
# sub folder :  copied-audio/Linkin Park/
# sub folder :  copied-audio/Living In Pretend/
# sub folder :  copied-audio/Living Tombstone/
# sub folder :  copied-audio/Loggins and Messina/
# sub folder :  copied-audio/London Symphony Orchestra/
# sub folder :  copied-audio/Louis Armstrong/
# sub folder :  copied-audio/Lovehatehero/
# sub folder :  copied-audio/Lucas Arts/
# sub folder :  copied-audio/Luciana Souza/
# sub folder :  copied-audio/Ludovico Einaudi/
# sub folder :  copied-audio/Luigi Boccherini/
# sub folder :  copied-audio/Lyre Le Temps/
# sub folder :  copied-audio/M.C. Hammer/
# sub folder :  copied-audio/MGMT/
# sub folder :  copied-audio/MOVITS/
# sub folder :  copied-audio/Madina Lake/
# sub folder :  copied-audio/Mae/
# sub folder :  copied-audio/Mandy Moore/
# sub folder :  copied-audio/Marius de Vries_Michelle De Vries_Stuart/
# sub folder :  copied-audio/Maroon 5/
# sub folder :  copied-audio/Martin O'Donnell & Michael Salvatori/
# sub folder :  copied-audio/Martin O'Donnell_Michael Salvatori/
# sub folder :  copied-audio/Massive Attack/
# sub folder :  copied-audio/Matchbox 20/
# sub folder :  copied-audio/Matt & Kim/
# sub folder :  copied-audio/Matt Fahey, Jennifer Taub And Josh Thoem/
# sub folder :  copied-audio/Matt Fahey/
# sub folder :  copied-audio/Matt and Kim/
# sub folder :  copied-audio/Maxwell Davies/
# sub folder :  copied-audio/Men Without Hats/
# sub folder :  copied-audio/Metric/
# sub folder :  copied-audio/Michael Andrews/
# sub folder :  copied-audio/Mike Morasky/
# sub folder :  copied-audio/Miracles of Modern Science/
# sub folder :  copied-audio/Moby & Oscar The Punk/
# sub folder :  copied-audio/Moby/
# sub folder :  copied-audio/Modest Mouse/
# sub folder :  copied-audio/Modest Mouse_Ratatat/
# sub folder :  copied-audio/Mogwai/
# sub folder :  copied-audio/Molly Jenson/
# sub folder :  copied-audio/Mono & World's End Girlfriend/
# sub folder :  copied-audio/Mop Mop/
# sub folder :  copied-audio/Motion City Soundtrack/
# sub folder :  copied-audio/Mozart/
# sub folder :  copied-audio/Mumford and Sons/
# sub folder :  copied-audio/Muse/
# sub folder :  copied-audio/My Brightest Diamond/
# sub folder :  copied-audio/My Chemical Romance/
# sub folder :  copied-audio/NOFX/
# sub folder :  copied-audio/NPR/
# sub folder :  copied-audio/Naive Thieves/
# sub folder :  copied-audio/Naruto/
# sub folder :  copied-audio/Nash Ensemble_Libor Pesek/
# sub folder :  copied-audio/Nasty Facts/
# sub folder :  copied-audio/Neon Trees/
# sub folder :  copied-audio/Neutral Milk Hotel/
# sub folder :  copied-audio/New Stories/
# sub folder :  copied-audio/Newton/
# sub folder :  copied-audio/Nick Cave & Warren Ellis/
# sub folder :  copied-audio/Nick Cave , Warren Ellis/
# sub folder :  copied-audio/Nickelback/
# sub folder :  copied-audio/Nintendo Games/
# sub folder :  copied-audio/Nirvana/
# sub folder :  copied-audio/No artist info/
# sub folder :  copied-audio/Nobuo Uematsu/
# sub folder :  copied-audio/Novak/
# sub folder :  copied-audio/Nox Arcana/
# sub folder :  copied-audio/O'Reilly Media Where 2.0 Conference/
# sub folder :  copied-audio/O-Zone/
# sub folder :  copied-audio/OCRemix/
# sub folder :  copied-audio/OSCON Europe 2005/
# sub folder :  copied-audio/Ocean Is Theory/
# sub folder :  copied-audio/Of Monsters and Men/
# sub folder :  copied-audio/Of Montreal/
# sub folder :  copied-audio/Offenbach/
# sub folder :  copied-audio/Ohio Valley Spirits/
# sub folder :  copied-audio/Ok Go/
# sub folder :  copied-audio/Olafur Arnalds/
# sub folder :  copied-audio/OneRepublic_Beyonce_Liam Murphy/
# sub folder :  copied-audio/Original Soundtrack/
# sub folder :  copied-audio/Original Soundtracks/
# sub folder :  copied-audio/Outkast/
# sub folder :  copied-audio/Pachelbel/
# sub folder :  copied-audio/Packy Lundholm/
# sub folder :  copied-audio/Papa Roach/
# sub folder :  copied-audio/Paramore/
# sub folder :  copied-audio/Parov Stelar feat. Anduze/
# sub folder :  copied-audio/Parov Stelar feat. Cleo Panther/
# sub folder :  copied-audio/Parov Stelar feat. Jerry Di Monza/
# sub folder :  copied-audio/Parov Stelar feat. Lilja Bloom/
# sub folder :  copied-audio/Parov Stelar feat. Max The Sax/
# sub folder :  copied-audio/Parov Stelar/
# sub folder :  copied-audio/Pascal Marcotte And The Randolph Carters/
# sub folder :  copied-audio/Paul Cardall/
# sub folder :  copied-audio/Paul Oakenfold/
# sub folder :  copied-audio/Peter Jennison/
# sub folder :  copied-audio/Peter Schilling/
# sub folder :  copied-audio/Philadelphia Orchestra, Riccardo Muti &/
# sub folder :  copied-audio/Philharmonia Moscow/
# sub folder :  copied-audio/Philharmonia Orchestra/
# sub folder :  copied-audio/Philip Glass/
# sub folder :  copied-audio/PiercingSight (composed by)/
# sub folder :  copied-audio/PiercingSight/
# sub folder :  copied-audio/Pinback/
# sub folder :  copied-audio/Pinchas Zukerman _ Mark Neikrug/
# sub folder :  copied-audio/Pink Floyd/
# sub folder :  copied-audio/Pink/
# sub folder :  copied-audio/PinkiePieSwear/
# sub folder :  copied-audio/Plumb/
# sub folder :  copied-audio/Podcasts/
# sub folder :  copied-audio/Ponyo/
# sub folder :  copied-audio/Portal/
# sub folder :  copied-audio/Pull Tiger Tail/
# sub folder :  copied-audio/Quadro Nuevo/
# sub folder :  copied-audio/Quantic Soul Orchestra/
# sub folder :  copied-audio/Quantic/
# sub folder :  copied-audio/Queen/
# sub folder :  copied-audio/R.E.M_/
# sub folder :  copied-audio/R.X.R.A/
# sub folder :  copied-audio/RJD2/
# sub folder :  copied-audio/Rachmaninov/
# sub folder :  copied-audio/Ramin Djawadi/
# sub folder :  copied-audio/Ramona Falls/
# sub folder :  copied-audio/Randy Edelman/
# sub folder :  copied-audio/Ratatat/
# sub folder :  copied-audio/Rebecca Marcotte And Josh Thoemke/
# sub folder :  copied-audio/Red Hot Chilli Peppers/
# sub folder :  copied-audio/Reel Big Fish/
# sub folder :  copied-audio/Reeves Gabrels/
# sub folder :  copied-audio/Requiem For A Dream/
# sub folder :  copied-audio/Reservoir Ticklers/
# sub folder :  copied-audio/Richard Searles/
# sub folder :  copied-audio/Ricky Martin/
# sub folder :  copied-audio/Riot Games/
# sub folder :  copied-audio/Riyu Kosaka/
# sub folder :  copied-audio/Rob Dougan/
# sub folder :  copied-audio/Rob Thomas/
# sub folder :  copied-audio/Robin Williams/
# sub folder :  copied-audio/Rodrigo y Gabriela/
# sub folder :  copied-audio/Roger Waters/
# sub folder :  copied-audio/Rostropovich/
# sub folder :  copied-audio/Roy Brown/
# sub folder :  copied-audio/Royal Liverpool Philharmonic orchestra/
# sub folder :  copied-audio/Royal Philharmonic Orchestra/
# sub folder :  copied-audio/Royksopp/
# sub folder :  copied-audio/Rupert Holmes/
# sub folder :  copied-audio/Russell Brower & The Eminence Symphony O/
# sub folder :  copied-audio/Rusted Root/
# sub folder :  copied-audio/Saliva/
# sub folder :  copied-audio/Saltillo/
# sub folder :  copied-audio/Santana/
# sub folder :  copied-audio/Saxon Shore/
# sub folder :  copied-audio/Schubert/
# sub folder :  copied-audio/Scissor Sisters/
# sub folder :  copied-audio/Scryden Broken Wings/
# sub folder :  copied-audio/Sean Paul/
# sub folder :  copied-audio/Shad/
# sub folder :  copied-audio/Shiny Toy Guns/
# sub folder :  copied-audio/Shostakovich/
# sub folder :  copied-audio/Sid Phillips/
# sub folder :  copied-audio/Sifl & Olly/
# sub folder :  copied-audio/Sigur Rós/
# sub folder :  copied-audio/Simple Plan/
# sub folder :  copied-audio/Sing It Loud/
# sub folder :  copied-audio/Sir Georg Solti & Wiener Philharmoniker/
# sub folder :  copied-audio/Sir Mix-A-Lot/
# sub folder :  copied-audio/Skream & Example/
# sub folder :  copied-audio/Skrillex/
# sub folder :  copied-audio/Slapbak/
# sub folder :  copied-audio/Slovak Philharmonic Orchestra/
# sub folder :  copied-audio/Smash Mouth/
# sub folder :  copied-audio/SmashMouth/
# sub folder :  copied-audio/Smile Empty Soul/
# sub folder :  copied-audio/Someone Still Loves You Boris Yeltsin/
# sub folder :  copied-audio/Someone Still Loves You, Boris Yeltsin/
# sub folder :  copied-audio/Sonny Rollins With the Modern Jazz Quart/
# sub folder :  copied-audio/Soul Position/
# sub folder :  copied-audio/Soundtrack/
# sub folder :  copied-audio/South Park/
# sub folder :  copied-audio/Spanish National orchestra/
# sub folder :  copied-audio/Spoon/
# sub folder :  copied-audio/Starting Line/
# sub folder :  copied-audio/Stevie Wonder/
# sub folder :  copied-audio/Sting & The Police/
# sub folder :  copied-audio/Street Fighter 4/
# sub folder :  copied-audio/Streetlight Manifesto/
# sub folder :  copied-audio/String Quartet Tribute/
# sub folder :  copied-audio/Stromae/
# sub folder :  copied-audio/Sublime/
# sub folder :  copied-audio/Super Furry Animals/
# sub folder :  copied-audio/Survivor/
# sub folder :  copied-audio/Swarms/
# sub folder :  copied-audio/System Of A Down/
# sub folder :  copied-audio/T. Colin Campbell/
# sub folder :  copied-audio/TAT/
# sub folder :  copied-audio/TJ & The Revo/
# sub folder :  copied-audio/TV on the Radio/
# sub folder :  copied-audio/TV_TV/
# sub folder :  copied-audio/Tamara McDonough/
# sub folder :  copied-audio/Tamara/
# sub folder :  copied-audio/Tangerine Dream/
# sub folder :  copied-audio/Tavener/
# sub folder :  copied-audio/Tchaikovsky/
# sub folder :  copied-audio/Tears for Fears/
# sub folder :  copied-audio/Ted Leo & the Pharmacists/
# sub folder :  copied-audio/Tegan & Sara/
# sub folder :  copied-audio/Tex Beneke/
# sub folder :  copied-audio/The 5, 6, 7, 8's/
# sub folder :  copied-audio/The Adicts/
# sub folder :  copied-audio/The All-American Rejects/
# sub folder :  copied-audio/The American Dollar/
# sub folder :  copied-audio/The Aquabats/
# sub folder :  copied-audio/The Arkham Carolers/
# sub folder :  copied-audio/The Ataris/
# sub folder :  copied-audio/The Avalanches/
# sub folder :  copied-audio/The Beatles/
# sub folder :  copied-audio/The Blow/
# sub folder :  copied-audio/The Bouncing Souls/
# sub folder :  copied-audio/The Brand New Heavies/
# sub folder :  copied-audio/The Clash/
# sub folder :  copied-audio/The Clockwork Quartet/
# sub folder :  copied-audio/The Darkness/
# sub folder :  copied-audio/The Decemberists/
# sub folder :  copied-audio/The Fray/
# sub folder :  copied-audio/The Friendly Indians/
# sub folder :  copied-audio/The Go! Train/
# sub folder :  copied-audio/The Gories/
# sub folder :  copied-audio/The H.P. Lovecraft Historical Society/
# sub folder :  copied-audio/The Homestuck Fan Musicians/
# sub folder :  copied-audio/The Hush Sound/
# sub folder :  copied-audio/The Ink Spots/
# sub folder :  copied-audio/The Intelligence/
# sub folder :  copied-audio/The Killers/
# sub folder :  copied-audio/The Kinks/
# sub folder :  copied-audio/The Limp Twins/
# sub folder :  copied-audio/The London Symphony Orchestra/
# sub folder :  copied-audio/The Magnetic Fields/
# sub folder :  copied-audio/The Maine/
# sub folder :  copied-audio/The Meatmean/
# sub folder :  copied-audio/The Mountain Goats/
# sub folder :  copied-audio/The New Pornographers/
# sub folder :  copied-audio/The Number Twelve Looks Like You/
# sub folder :  copied-audio/The Offspring/
# sub folder :  copied-audio/The Piano Guys/
# sub folder :  copied-audio/The Pixies/
# sub folder :  copied-audio/The Police/
# sub folder :  copied-audio/The Posies/
# sub folder :  copied-audio/The Proclaimers/
# sub folder :  copied-audio/The Ramones/
# sub folder :  copied-audio/The Rolling Stones/
# sub folder :  copied-audio/The Section Quartet/
# sub folder :  copied-audio/The Shins/
# sub folder :  copied-audio/The Strokes/
# sub folder :  copied-audio/The Sugarhill Gang/
# sub folder :  copied-audio/The Vandals/
# sub folder :  copied-audio/The Vapors/
# sub folder :  copied-audio/The Venetia Fair/
# sub folder :  copied-audio/The Verve/
# sub folder :  copied-audio/The White Tie Affair/
# sub folder :  copied-audio/The Who/
# sub folder :  copied-audio/The Winterpills/
# sub folder :  copied-audio/The _Once_ Soundtrack/
# sub folder :  copied-audio/Theophany/
# sub folder :  copied-audio/There for Tomorrow/
# sub folder :  copied-audio/These Green Eyes/
# sub folder :  copied-audio/Thin Lizzy/
# sub folder :  copied-audio/Third Eye Blind/
# sub folder :  copied-audio/Thomas Newman/
# sub folder :  copied-audio/Tilly and the Wall/
# sub folder :  copied-audio/Tim Janis/
# sub folder :  copied-audio/Timothy Vajda/
# sub folder :  copied-audio/Tiny Tim/
# sub folder :  copied-audio/Tomoyasu Hotei/
# sub folder :  copied-audio/Toshiro Masuda/
# sub folder :  copied-audio/Train/
# sub folder :  copied-audio/Trans-Siberian Orchestra/
# sub folder :  copied-audio/Transformers/
# sub folder :  copied-audio/Travis Lien/
# sub folder :  copied-audio/Trevor Morris/
# sub folder :  copied-audio/Trevor Rabin/
# sub folder :  copied-audio/Two Steps From Hell/
# sub folder :  copied-audio/Tycho/
# sub folder :  copied-audio/Tyler Bates/
# sub folder :  copied-audio/U2/
# sub folder :  copied-audio/Ulster Orchestra/
# sub folder :  copied-audio/Uncle Brian/
# sub folder :  copied-audio/Valencia/
# sub folder :  copied-audio/Vampire Weekend/
# sub folder :  copied-audio/Vanessa-Mae/
# sub folder :  copied-audio/Vangelis/
# sub folder :  copied-audio/Vanilla Ice/
# sub folder :  copied-audio/Varios interpretes/
# sub folder :  copied-audio/Various Artists/
# sub folder :  copied-audio/Various/
# sub folder :  copied-audio/Vertical Horizon/
# sub folder :  copied-audio/Viva Voce/
# sub folder :  copied-audio/WGBH Science Unit/
# sub folder :  copied-audio/Walk The Moon/
# sub folder :  copied-audio/Wang Lee Hom/
# sub folder :  copied-audio/Wayne Jones/
# sub folder :  copied-audio/Weezer/
# sub folder :  copied-audio/Weird Al Yankovic/
# sub folder :  copied-audio/WhiteNoise Lab/
# sub folder :  copied-audio/Will Post/
# sub folder :  copied-audio/Witches/
# sub folder :  copied-audio/Xihilisk/
# sub folder :  copied-audio/Yeah Yeah Yeahs/
# sub folder :  copied-audio/Yes/
# sub folder :  copied-audio/Yiruma/
# sub folder :  copied-audio/Yo La Tengo/
# sub folder :  copied-audio/Yo-Yo Ma/
# sub folder :  copied-audio/Youth Group/
# sub folder :  copied-audio/Zoe Keating/
# sub folder :  copied-audio/_Weird Al_ Yankovic/
# sub folder :  copied-audio/_unsorted/
